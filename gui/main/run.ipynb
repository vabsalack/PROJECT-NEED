# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'need_01.ui'
#
# Created by: PyQt5 UI code generator 5.15.7
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.

from PyQt5 import QtCore, QtGui, QtWidgets

class Ui_Dialog(object):
    def setupUi(self, Dialog):
        Dialog.setObjectName("Dialog")
        Dialog.setEnabled(True)
        Dialog.resize(1121, 811)
        self.line = QtWidgets.QFrame(Dialog)
        self.line.setGeometry(QtCore.QRect(110, -20, 20, 841))
        self.line.setFrameShape(QtWidgets.QFrame.VLine)
        self.line.setFrameShadow(QtWidgets.QFrame.Sunken)
        self.line.setObjectName("line")
        self.left_knee = QtWidgets.QLabel(Dialog)
        self.left_knee.setGeometry(QtCore.QRect(640, 320, 481, 481))
        self.left_knee.setText("")
        self.left_knee.setPixmap(QtGui.QPixmap(lknee_stimp))
        self.left_knee.setScaledContents(True)
        self.left_knee.setObjectName("left_knee")
        self.original_image_preview = QtWidgets.QLabel(Dialog)
        self.original_image_preview.setGeometry(QtCore.QRect(130, 10, 231, 281))
        self.original_image_preview.setText("")
        self.original_image_preview.setPixmap(QtGui.QPixmap(preview_stimp))
        self.original_image_preview.setScaledContents(True)
        self.original_image_preview.setObjectName("original_image_preview")
        self.right_knee = QtWidgets.QLabel(Dialog)
        self.right_knee.setGeometry(QtCore.QRect(130, 320, 481, 481))
        self.right_knee.setText("")
        self.right_knee.setPixmap(QtGui.QPixmap(rknee_stimp))
        self.right_knee.setScaledContents(True)
        self.right_knee.setObjectName("right_knee")
        self.instruction_one = QtWidgets.QLabel(Dialog)
        self.instruction_one.setGeometry(QtCore.QRect(10, 30, 91, 21))
        self.instruction_one.setObjectName("instruction_one")
        self.button_open = QtWidgets.QPushButton(Dialog)
        self.button_open.setGeometry(QtCore.QRect(10, 70, 91, 81))
        font = QtGui.QFont()
        font.setPointSize(8)
        self.button_open.setFont(font)
        self.button_open.setObjectName("button_open")
        self.button_segment = QtWidgets.QPushButton(Dialog)
        self.button_segment.setGeometry(QtCore.QRect(10, 170, 91, 81))
        font = QtGui.QFont()
        font.setPointSize(8)
        self.button_segment.setFont(font)
        self.button_segment.setObjectName("button_segment")
        self.button_reset = QtWidgets.QPushButton(Dialog)
        self.button_reset.setGeometry(QtCore.QRect(10, 270, 91, 81))
        font = QtGui.QFont()
        font.setPointSize(8)
        self.button_reset.setFont(font)
        self.button_reset.setObjectName("button_save")
        self.image_name = QtWidgets.QLabel(Dialog)
        self.image_name.setGeometry(QtCore.QRect(400, 10, 681, 31))
        self.image_name.setObjectName("image_name")
        self.bounding_box = QtWidgets.QLabel(Dialog)
        self.bounding_box.setGeometry(QtCore.QRect(400, 50, 681, 31))
        self.bounding_box.setObjectName("bounding_box")
        self.propability = QtWidgets.QLabel(Dialog)
        self.propability.setGeometry(QtCore.QRect(400, 90, 681, 31))
        self.propability.setObjectName("propability")
        self.save_location = QtWidgets.QLabel(Dialog)
        self.save_location.setGeometry(QtCore.QRect(400, 130, 681, 31))
        self.save_location.setObjectName("save_location")
        
        #importing model
        print(">importing kyolo model..")
        from ultralytics import YOLO
        self.model = YOLO(model_p)
        print(">importing model successful..")
        
        #filename
        self.filename = ""

        self.retranslateUi(Dialog)
        QtCore.QMetaObject.connectSlotsByName(Dialog)
        
        self.button_open.clicked.connect(self.button_open_clicked)
        self.button_reset.clicked.connect(self.button_reset_clicked)
        self.button_segment.clicked.connect(self.button_segment_clicked)
 
       
        
    def button_open_clicked(self):
        print(">loading input image..")
        self.filename = QtWidgets.QFileDialog.getOpenFileName(self.button_open,
                                               "Open Image", 
                                               "/home/keva/Documents/PROJECT-NEED/d-knee-f-yolov8", 
                                               "Image Files (*.png *.jpg)")
        
        self.original_image_preview.setPixmap(QtGui.QPixmap(self.filename[0]))
        print(self.filename[0])
        print(">loding input image successful..")
        
        self.image_name.setText(f"Image name: {self.filename[0].split('/')[-1]}")
        self.image_name.adjustSize()
        

    def button_reset_clicked(self):
        
        self.original_image_preview.setPixmap(QtGui.QPixmap(preview_stimp))
        self.right_knee.setPixmap(QtGui.QPixmap(rknee_stimp))
        self.left_knee.setPixmap(QtGui.QPixmap(lknee_stimp))
        
        self.filename = ""
        print(">reset successful..")
        
        self.image_name.setText("Image name: ")
        self.image_name.adjustSize()
        
        self.bounding_box.setText("bbx: ")
        self.bounding_box.adjustSize()
        
    def button_segment_clicked(self):

        if  self.filename:
            print(">segmenting started..")
            
            img_p = self.filename[0]
            
            #inference input image
            results = self.model.predict(source=img_p,
                                   save_crop=True)
            
            
            save_image_name = img_p.split('/')[-1].split('.rf.')[0]
            save_p = '/home/keva/Documents/PROJECT-NEED/gui/main/runs/detect/predict/crops/Knee/'
            
            print(save_image_name)
            
            names = []
            for nm in os.listdir(save_p):
                if save_image_name in nm:
                    names.append(nm)
            print(names)
            
            boxs = results[0].boxes
            
            if len(boxs) > 1:
                lk = save_p + names[0]
                rk = save_p + names[1]
                
                self.right_knee.setPixmap(QtGui.QPixmap(rk))
                self.left_knee.setPixmap(QtGui.QPixmap(lk))
                
            else:
                rk = save_p + names[0]
                self.right_knee.setPixmap(QtGui.QPixmap(rk))
                self.left_knee.setPixmap(QtGui.QPixmap(lknee_stimp))
                                 
            self.bounding_box.setText(f"BBx coordinates: {float(boxs[0].data[0][0]): .1f} {float(boxs[0].data[0][1]): .1f} {float(boxs[0].data[0][2]): .1f} {float(boxs[0].data[0][3]): .1f}")                          
            self.bounding_box.adjustSize()
                
            self.propability.setText(f"Accuracy: {float(boxs[0].conf)*100:.1f}%")
            self.propability.adjustSize()
        
        print(">segmenting completed..")
        
    def retranslateUi(self, Dialog):
        _translate = QtCore.QCoreApplication.translate
        Dialog.setWindowTitle(_translate("Dialog", "NEED"))
        self.instruction_one.setText(_translate("Dialog", " Controls"))
        self.button_open.setText(_translate("Dialog", "OPEN"))
        self.button_segment.setText(_translate("Dialog", "SEGEMENT"))
        self.button_reset.setText(_translate("Dialog", "RESET"))
        self.image_name.setText(_translate("Dialog", "Image name: "))
        self.bounding_box.setText(_translate("Dialog", "BBox coordinates: "))
        self.propability.setText(_translate("Dialog", "Accuracy: "))
                                             
        self.save_location.setText(_translate("Dialog", "save loction: /home/keva/Documents/PROJECT-NEED/gui/main/runs/detect/predict/"))
        self.save_location.adjustSize()

if __name__ == "__main__":
    #static images
    model_p = "/home/keva/Documents/PROJECT-NEED/gui/main/runs/detect/train/weights/best.pt"
    preview_stimp = "/home/keva/Documents/PROJECT-NEED/gui/main/pictures/dot.png"
    lknee_stimp = "/home/keva/Documents/PROJECT-NEED/gui/main/pictures/grid.png"
    rknee_stimp= "/home/keva/Documents/PROJECT-NEED/gui/main/pictures/grid.png"
    
    import sys, os
    app = QtWidgets.QApplication(sys.argv)
    Dialog = QtWidgets.QDialog()
    ui = Ui_Dialog()
    ui.setupUi(Dialog)
    Dialog.show()
    sys.exit(app.exec_())
# Out:
# >importing kyolo model..
# >importing model successful..
# >loading input image..
#
# >loding input image successful..
# >reset successful..
# >loading input image..
# /home/keva/Documents/PROJECT-NEED/d-knee-f-yolov8/test/images/f8bf826b-195_1609135563741_2_jpg.rf.e18e94142fb28ef6aae70644bdf67f4a.jpg
# >loding input image successful..
# >segmenting started..
# image 1/1 /home/keva/Documents/PROJECT-NEED/d-knee-f-yolov8/test/images/f8bf826b-195_1609135563741_2_jpg.rf.e18e94142fb28ef6aae70644bdf67f4a.jpg: 640x640 1 Knee, 54.8ms
# Speed: 5.3ms preprocess, 54.8ms inference, 17.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# f8bf826b-195_1609135563741_2_jpg
# ['f8bf826b-195_1609135563741_2_jpg.rf.jpg']
# >segmenting completed..
# >loading input image..
# /home/keva/Desktop/test/2ba8323e-360_1611219710004_3_jpg.rf.374114906dd43e7e744190f1c728e53b.jpg
# >loding input image successful..
# image 1/1 /home/keva/Desktop/test/2ba8323e-360_1611219710004_3_jpg.rf.374114906dd43e7e744190f1c728e53b.jpg: 640x640 2 Knees, 56.4ms
# Speed: 16.8ms preprocess, 56.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# >segmenting started..
# 2ba8323e-360_1611219710004_3_jpg
# ['2ba8323e-360_1611219710004_3_jpg.rf.jpg', '2ba8323e-360_1611219710004_3_jpg.rf2.jpg']
# >segmenting completed..
